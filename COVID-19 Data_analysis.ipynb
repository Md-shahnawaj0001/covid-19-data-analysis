# %% [markdown]
# # COVID19 Data Analysis

# %%
#importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Reading the data from csv

# %%
#loading the covid19_Confirmed_dataset
covid_data=pd.read_csv("Dataset/covid19_Confirmed_dataset.csv")
covid_data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_data.shape
# Out:
# (266, 104)

# %% [markdown]
# ## Droping the useless columns from the data

# %%
covid_data.drop(labels=['Lat','Long'],axis=1,inplace=True)

# %%
covid_data
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
covid_data.shape
# Out:
# (266, 102)

# %% [markdown]
# ## Aggregating the rows by country

# %%
covid_data_aggregated=covid_data.groupby('Country/Region').sum()
covid_data_aggregated.head(10)
# Out:
#                                                         Province/State  \
# Country/Region
# Afghanistan                                                          0
# Albania                                                              0
# Algeria                                                              0
# Andorra                                                              0
# Angola                                                               0
# Antigua and Barbuda                                                  0
# Argentina                                                            0
# Armenia                                                              0
# Australia            Australian Capital TerritoryNew South WalesNor...
# Austria                                                              0
#
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# ...

# %% [markdown]
# ## visualizing data related to country

# %%
covid_data_aggregated.loc['India'].plot()
# Out:
# <Axes: >

# %%
gp=covid_data_aggregated.loc[:,['4/21/20','4/22/20','4/23/20']]
print(gp.loc['India'])
gp.loc['India'].plot()
# Out:
# 4/21/20    20080
# 4/22/20    21370
# 4/23/20    23077
# Name: India, dtype: int64
# <Axes: >

# %% [markdown]
# ## Calculating and ploting first derivative of the curve

# %%
covid_data_aggregated.loc['India'].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Finding the maximum infected rate

# %%
covid_data_aggregated.loc["India"].diff().max()
# Out:
# 1893

# %%
countries = list(covid_data_aggregated.index)
max_infected_rates = []

for country in countries:
    # Select only numeric values (ignore country names, dates, etc.)
    numeric_data = covid_data_aggregated.loc[country].select_dtypes(include=['number'])
    
    # Calculate the max increase
    max_infected_rates.append(numeric_data.diff().max().max())

covid_data_aggregated["max_infected_rates"] = max_infected_rates
covid_data_aggregated
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30152\3613400219.py in ?()
#       2 max_infected_rates = []
#       3
#       4 for country in countries:
#       5     # Select only numeric values (ignore country names, dates, etc.)
# ----> 6     numeric_data = covid_data_aggregated.loc[country].select_dtypes(include=['number'])
#       7
#       8     # Calculate the max increase
#       9     max_infected_rates.append(numeric_data.diff().max().max())
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...

# %%
covid_data=pd.DataFrame(covid_data_aggregated['max_infected_rates'])

# %%
covid_data.head()

# %% [markdown]
# # World wide happiness dataset

# %% [markdown]
# ## Loding the world wide happiness dataset

# %%
world_happiness_data=pd.read_csv("Dataset/worldwide_happiness_report.csv")
world_happiness_data.head()

# %% [markdown]
# ## drop useless columns in the dataset

# %%
columns_to_drop=['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_data.drop(columns_to_drop, axis=1, inplace=True)
world_happiness_data.head()

# %% [markdown]
# ## changig th indices of the dataset

# %%
world_happiness_data.groupby('Country or region')
world_happiness_data.head()

# %% [markdown]
# ## join the two datasets that is prepared

# %%
#covid data
covid_data.head()

# %%
world_happiness_data=world_happiness_data.rename(columns={'Country or region':'Country/Region'})

# %%
world_happiness_data.head()

# %%
data=pd.merge(world_happiness_data,covid_data,on='Country/Region')

# %%
data

# %% [markdown]
# ## ploting GDP Vs Manximum infected rate

# %%
x=data['GDP per capita']
y=data['max_infected_rates']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Ploting Social support vs maximum infected rate

# %%
x=data['Social support']
y=data['max_infected_rates']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Ploting Healthy life vs  maximum infected rate

# %%
x=data['Healthy life expectancy']
y=data['max_infected_rates']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Ploting Freedom to make life choices vs  maximum infected rate

# %%
x=data['Freedom to make life choices']
y=data['max_infected_rates']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
